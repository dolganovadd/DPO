# %% [markdown]
# # Первый computational notebook

# %% [markdown]
# Долганова Диана Евгеньевна ИВТ-23-1Б

# %% [markdown]
# ## Упражнение: Вычисление числа pi с помощью метода Монте-Карло

# %% [markdown]
# 1. Создайте новый блокнот , назовите его и добавьте заголовок (ячейку в формате
# markdown ниже).

# %% [markdown]
# # Вычисление числа pi с помощью метода Монте - Карло

# %% [markdown]
# 2. Зафиксируйте соответствующие формулы в новой ячейке (ячейке с Markdown):

# %% [markdown]
# - Площадь квадрата: $s = (2 r)^2$
# - Площадь круга: $c = \pi r^2$
# - $c/s = (\pi r^2)/(4r^2) = \pi /4$
# - $pi = 4 * c/s$

# %% [markdown]
# 3. Добавьте изображение для пояснения концепции (ячейка markdown):

# %% [markdown]
# ![](https://raw.githubusercontent.com/coderefinery/jupyter/main/example/darts.svg)

# %% [markdown]
# 4. Импортируйте два модуля, которые нам понадобятся (ячейка с кодом):

# %%
# !python -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
import matplotlib.pyplot as plt

# %% [markdown]
# 5. Инициализируйте количество точек (ячейка с кодом):

# %%
num_points = 1000

# %% [markdown]
# 6. Броски дротиков (ячейка с кодом):

# %%
points = []
hits = 0
for _ in range(num_points):
    x, y = random.random(), random.random()
    if x*x + y*y < 1.0:
        hits += 1
        points.append((x, y, "blue"))
    else:
        points.append((x, y, "red"))

# %% [markdown]
# 7. Построение графика результатов (ячейка с кодом):

# %%
x, y, colors = zip(*points)

fig, ax = plt.subplots() 
fig.set_size_inches(6.0, 6.0)

ax.scatter(x, y, c=colors)

# %% [markdown]
# 8. Вычислите оценку для pi (ячейка с кодом):

# %%
fraction = hits / num_points
print("pi = ", 4 * fraction)
# Out:
# pi =  3.16

# %% [markdown]
# ## Блокноты и контроль версий

# %% [markdown]
# ### Упражнение: что происходит без `requirements.txt`?

# %%
# !python -m pip install -r requirements.txt
# Out:
# Collecting pandas==2.2.3 (from -r requirements.txt (line 1))
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 2)) (3.9.2)
# Collecting seaborn==0.13.2 (from -r requirements.txt (line 3))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 1)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.3->-r requirements.txt (line 1))
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3->-r requirements.txt (line 1))
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from matplotlib==3.9.2->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\диана долганова\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 1)) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.5 MB 3.9 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.5 MB 3.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.5 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 3.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.5 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.5 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.5 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 3.7 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas, seaborn
# Successfully installed pandas-2.2.3 pytz-2024.2 seaborn-0.13.2 tzdata-2024.2

# %% [markdown]
# ### Добавление виджета в задание 1

# %%
from matplotlib import pyplot
import random
from ipywidgets import interact, widgets

# %matplotlib inline


def throw_darts(num_points):
    points = []
    hits = 0
    for _ in range(num_points):
        x, y = random.random(), random.random()
        if x*x + y*y < 1.0:
            hits += 1
            points.append((x, y, True))
        else:
            points.append((x, y, False))
    fraction = hits / num_points
    pi = 4 * fraction
    return pi, points


def create_plot(points):
    x, y, colors = zip(*points)
    pyplot.scatter(x, y, c=colors)


def experiment(num_points):
    pi, points = throw_darts(num_points)
    create_plot(points)
    print("approximation:", pi)
    
interact(experiment, num_points=widgets.IntSlider(min=100, max=10000, step=100, value=1000))
# Out:
# interactive(children=(IntSlider(value=1000, description='num_points', max=10000, min=100, step=100), Output())…
# <function __main__.experiment(num_points)>
